# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../lightning_logs/version_97/metrics.csv')
df.head()
# Out:
#    epoch  step  train/acc  val/acc
# 0      0    49   0.072670      NaN
# 1      0    99   0.020917      NaN
# 2      0   149   0.051709      NaN
# 3      0   199   0.105613      NaN
# 4      0   249   0.056968      NaN

# %%
plt.plot(df["step"], df["train/acc"], label="train")
plt.plot(df["step"], df["val/acc"], label="val")

plt.legend()

plt.show()
